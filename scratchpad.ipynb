# %%
#open pkl file
import pandas as pd
import pickle
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
import os
with open('datafiles/mergedOuterDf.pkl', 'rb') as f:
    df = pickle.load(f)
# Out:
# C:\Users\case4\AppData\Local\Temp\ipykernel_30632\1250384199.py:8: DeprecationWarning: numpy.core.numeric is deprecated and has been renamed to numpy._core.numeric. The numpy._core namespace contains private NumPy internals and its use is discouraged, as NumPy internals can change without warning in any release. In practice, most real-world usage of numpy.core is to access functionality in the public NumPy API. If that is the case, use the public NumPy API. If not, you are using NumPy internals. If you would still like to access an internal attribute, use numpy._core.numeric._frombuffer.
#   df = pickle.load(f)

# %%
df.head()
# Out:
#    Status/Disposal  Ear Tag  Ear Tag Location  Brand Brand Location Tattoo  \
# 0                0      NaN               NaN  C0271             RH   8075
# 1                0      NaN               NaN  C0271             RH   9071
# 2                0      NaN               NaN  C0271             RH   1027
# 3                0      NaN               NaN  C0271             RH   1077
# 4                0      NaN               NaN  C0271             RH   1080
#
#   Tattoo Location  Other ID  Other ID Location                         Name  \
# 0              LE       NaN                NaN  ARTESIAN CATTLE C0271188075
# 1             NaN       NaN                NaN         ARTESIAN CATTLE 9071
# 2             NaN       NaN                NaN   ARTESIAN 1603Z OLIVIA 1027
# 3             NaN       NaN                NaN      ARTESIAN 2163A AVA 1077
# 4             NaN       NaN                NaN         ARTESIAN CATTLE 1080
#
#   Registration Number                        Breeder  Breeder Member Number  \
# 0            1A128345  ARTESIAN CATTLE & FARMING LLC                  291.0
# 1            1A151658  ARTESIAN CATTLE & FARMING LLC                  291.0
# 2            1A217728  ARTESIAN CATTLE & FARMING LLC                  291.0
# 3            1A217778  ARTESIAN CATTLE & FARMING LLC                  291.0
# 4            1A217781  ARTESIAN CATTLE & FARMING LLC                  291.0
#
#                            Owner  Owner Member Number Date of Birth  \
# 0  ARTESIAN CATTLE & FARMING LLC                291.0      3/5/2018
# 1  ARTESIAN CATTLE & FARMING LLC                291.0     2/26/2019
# 2  ARTESIAN CATTLE & FARMING LLC                291.0     3/16/2021
# 3          ROCKY MILL CATTLE CO.               1668.0     2/24/2021
# 4  ARTESIAN CATTLE & FARMING LLC                291.0     2/22/2021
#
#   Birth Method     Sire      Dam     Status Type or Sex  Percent Purebred  \
# 0           NS  AF31519   X93873     Active           C               NaN
# 1           NS  AF36497   X94219     Active           C               NaN
# 2           NS  AF36497   X93901     Active           C               NaN
# 3           NS  AF42330  X209885  Reference           C               NaN
# 4           NS  AF42330  X209905     Active           C               NaN
#
#    Breed Breed 1 Breed 2 Breed 3  Breed Comp 1  Breed Comp 2  Breed Comp 3  \
# 0    NaN      AA      AN      XX          50.0          25.0          25.0
# 1    NaN      AA      CH      XX          50.0          25.0          25.0
# 2    NaN      AA      AN      XX          50.0          25.0          25.0
# 3    NaN      AA      AR     NaN          50.0          50.0           NaN
# 4    NaN      AA      AR     NaN          50.0          50.0           NaN
#
#   Horns  Color Markings EPDType  EPD Reporting Period  CED  CED Acc   BW  \
# 0     P             NaN       P            20240808.0 -0.5     0.10  0.4
# 1     P             NaN       P            20240808.0 -3.8     0.12  2.3
# 2     P             NaN       P            20240808.0 -3.8     0.12  2.3
# 3     P             NaN       P            20240808.0 -2.6     0.13  2.1
# 4     P             NaN       P            20240808.0 -5.1     0.11  2.1
#
#    BW Acc    WW  WW Acc    YW  YW Acc    MK  MK Acc       TM  \
# 0    0.08  47.0    0.06  83.0    0.01  24.0    0.04  46.9990
# 1    0.08  46.0    0.05  84.0    0.01  26.0    0.04  49.4180
# 2    0.08  46.0    0.05  84.0    0.01  26.0    0.04  49.4180
# 3    0.08  42.0    0.05  77.0    0.01  27.0    0.04  48.2155
# 4    0.08  42.0    0.05  77.0    0.01  27.0    0.04  48.2155
#
#    Calving Ease Maternal EPD  Calving Ease Maternal Acc  \
# 0                        NaN                        NaN
# 1                        NaN                        NaN
# 2                        NaN                        NaN
# 3                        NaN                        NaN
# 4                        NaN                        NaN
#
#    Scrotal Circumference EPD  Scrotal Circumference Acc  Ribeye Area EPD  \
# 0                        NaN                        NaN              NaN
# 1                        NaN                        NaN              NaN
# 2                        NaN                        NaN              NaN
# 3                        NaN                        NaN              NaN
# 4                        NaN                        NaN              NaN
#
#    Ribeye Area Acc  Marbling EPD  Marbling Acc  Fat Thickness EPD  \
# 0              NaN           NaN           NaN                NaN
# 1              NaN           NaN           NaN                NaN
# 2              NaN           NaN           NaN                NaN
# 3              NaN           NaN           NaN                NaN
# 4              NaN           NaN           NaN                NaN
#
#    Fat Thickness Acc  Carcass Weight EPD  Carcass Weight  Acc  \
# 0                NaN                 NaN                  NaN
# 1                NaN                 NaN                  NaN
# 2                NaN                 NaN                  NaN
# 3                NaN                 NaN                  NaN
# 4                NaN                 NaN                  NaN
#
#    Percent Retail Cuts EPD  Percent Retail Cuts Acc  Intramuscular Fat EPD  \
# 0                      NaN                      NaN                    NaN
# 1                      NaN                      NaN                    NaN
# 2                      NaN                      NaN                    NaN
# 3                      NaN                      NaN                    NaN
# 4                      NaN                      NaN                    NaN
#
#    Intramuscular Fat Acc  Birth Weight  Adjusted Birth Weight  \
# 0                    NaN           0.0                    NaN
# 1                    NaN           0.0                    NaN
# 2                    NaN           0.0                    NaN
# 3                    NaN           NaN                    NaN
# 4                    NaN           0.0                    NaN
#
#   Birth Contemp Group  Birth contemporaries  Birth Weight Ratio  Birth Height  \
# 0           6144-6271                  40.0                 NaN           NaN
# 1             15786-6                  22.0                 NaN           NaN
# 2             18216-3                  66.0                 NaN           NaN
# 3                 NaN                   NaN                 NaN           NaN
# 4             18217-1                  13.0                 NaN           NaN
#
#    Calving Ease  Birth Code  Nurse Code  Twin code  Dam Teat Score  \
# 0           1.0         NaN         NaN        1.0             NaN
# 1           1.0         NaN         NaN        1.0             NaN
# 2           1.0         NaN         NaN        1.0             NaN
# 3           NaN         NaN         NaN        NaN             NaN
# 4           1.0         NaN         NaN        1.0             NaN
#
#    Dam Udder Score  Dam Gestation Length Weaning Date Weaning Weight Date  \
# 0              NaN                   NaN          NaN                 NaN
# 1              NaN                   NaN          NaN                 NaN
# 2              NaN                   NaN          NaN                 NaN
# 3              NaN                   NaN          NaN                 NaN
# 4              NaN                   NaN          NaN                 NaN
#
#    Weaning Weight  Adjusted Weaning Weight Weaning Contemp Group  \
# 0             NaN                      NaN                   NaN
# 1             NaN                      NaN                   NaN
# 2             NaN                      NaN                   NaN
# 3             NaN                      NaN                   NaN
# 4             NaN                      NaN                   NaN
#
#    Weaning Contemporaries  Weaning Weight Ratio  Weaning WDA  Weaning Height  \
# 0                     NaN                   NaN          NaN             NaN
# 1                     NaN                   NaN          NaN             NaN
# 2                     NaN                   NaN          NaN             NaN
# 3                     NaN                   NaN          NaN             NaN
# 4                     NaN                   NaN          NaN             NaN
#
#    Weaning Frame Score  Weaning Mgmt Code Weaning Pasture Code  \
# 0                  NaN                NaN                  NaN
# 1                  NaN                NaN                  NaN
# 2                  NaN                NaN                  NaN
# 3                  NaN                NaN                  NaN
# 4                  NaN                NaN                  NaN
#
#    Weaning Sheath/Namvel Yearling Date Yearling Weight Date  Yearling Weight  \
# 0                    NaN           NaN                  NaN              NaN
# 1                    NaN           NaN                  NaN              NaN
# 2                    NaN           NaN                  NaN              NaN
# 3                    NaN           NaN                  NaN              NaN
# 4                    NaN           NaN                  NaN              NaN
#
#    Adjusted Yearling Weight Yearling Contemp Group  Yearling Contemporaries  \
# 0                       NaN                    NaN                      NaN
# 1                       NaN                    NaN                      NaN
# 2                       NaN                    NaN                      NaN
# 3                       NaN                    NaN                      NaN
# 4                       NaN                    NaN                      NaN
#
#    Yearling Weight Ratio  Yearling WDA  Yearling ADG  Yearling ADG Ratio  \
# 0                    NaN           NaN           NaN                 NaN
# 1                    NaN           NaN           NaN                 NaN
# 2                    NaN           NaN           NaN                 NaN
# 3                    NaN           NaN           NaN                 NaN
# 4                    NaN           NaN           NaN                 NaN
#
#    Yearling Height  Yearling Frame Score  Yearling Mgmt Code  \
# 0              NaN                   NaN                 NaN
# 1              NaN                   NaN                 NaN
# 2              NaN                   NaN                 NaN
# 3              NaN                   NaN                 NaN
# 4              NaN                   NaN                 NaN
#
#   Yearling Pasture Code  Yearling Sheath/Navel  Growth Idx
# 0                   NaN                    NaN      69.716
# 1                   NaN                    NaN      65.092
# 2                   NaN                    NaN      65.092
# 3                   NaN                    NaN      59.584
# 4                   NaN                    NaN      59.584

# %%
display(df.dtypes)
# Out:
# Year                                  float64
# Season                                float64
# Reg No                                 object
# Name                                   object
# Tattoo                                 object
# CED                                   float64
# CED Acc                               float64
# BW                                    float64
# BW Acc                                float64
# WW                                    float64
# WW Acc                                float64
# YW                                    float64
# YW Acc                                float64
# Milk                                  float64
# Milk Acc                              float64
# Total Maternal                        float64
# Growth Idx                            float64
# CM_Status/Disposal                      int64
# CM_Brand                               object
# CM_Brand Location                      object
# CM_Tattoo                              object
# CM_Tattoo Location                     object
# CM_Name                                object
# CM_Breeder                             object
# CM_Breeder Member Number              float64
# CM_Owner                               object
# CM_Owner Member Number                float64
# CM_Date of Birth               datetime64[ns]
# CM_Birth Method                        object
# CM_Sire                                object
# CM_Dam                                 object
# CM_Status                              object
# CM_Type or Sex                         object
# CM_Breed 1                             object
# CM_Breed 2                             object
# CM_Breed 3                             object
# CM_Breed Comp 1                       float64
# CM_Breed Comp 2                       float64
# CM_Breed Comp 3                       float64
# CM_Horns                               object
# CM_EPDType                             object
# CM_EPD Reporting Period               float64
# CM_Calving Ease Direct EPD            float64
# CM_Calving Ease Direct Acc            float64
# CM_Birth Weight EPD                   float64
# CM_Birth Weight Acc                   float64
# CM_Weaning Weight EPD                 float64
# CM_Weaning Weight Acc                 float64
# CM_Yearling Weight EPD                float64
# CM_Yearling Weight Acc                float64
# CM_Milk EPD                           float64
# CM_Milk Acc                           float64
# CM_Total Maternal EPD                 float64
# CM_Birth Weight                       float64
# CM_Adjusted Birth Weight              float64
# CM_Birth Contemp Group                 object
# CM_Birth contemporaries               float64
# CM_Birth Weight Ratio                 float64
# CM_Calving Ease                       float64
# CM_Twin code                          float64
# CM_Weaning Date                        object
# CM_Weaning Weight Date                 object
# CM_Weaning Weight                     float64
# CM_Adjusted Weaning Weight            float64
# CM_Weaning Contemp Group               object
# CM_Weaning Contemporaries             float64
# CM_Weaning Weight Ratio               float64
# CM_Weaning WDA                        float64
# CM_Weaning Mgmt Code                  float64
# CM_Weaning Pasture Code                object
# CM_Yearling Date                       object
# CM_Yearling Weight Date                object
# CM_Yearling Weight                    float64
# CM_Adjusted Yearling Weight           float64
# CM_Yearling Contemp Group              object
# CM_Yearling Contemporaries            float64
# CM_Yearling Weight Ratio              float64
# CM_Yearling WDA                       float64
# CM_Yearling ADG                       float64
# CM_Yearling Mgmt Code                 float64
# CM_Yearling Pasture Code               object
# dtype: object

# %%
df = df[(df["CM_Owner"] == "ARTESIAN CATTLE & FARMING LLC") & (df["CM_Status/Disposal"] == 0)].count()

# %%
df.head(1)
# Out:
#      Year      Season    Reg No                         Name Tattoo    CED  \
# 0  2024.0  20240808.0  1A128345  ARTESIAN CATTLE C0271188075   8075 -0.463
#
#    CED Acc     BW  BW Acc     WW  WW Acc      YW  YW Acc    Milk  Milk Acc  \
# 0    0.103  0.384   0.081  46.94   0.059  83.453    0.01  23.529     0.042
#
#    Total Maternal  Growth Idx  CM_Status/Disposal  CM_Ear Tag  \
# 0          46.999      83.066                   0         NaN
#
#    CM_Ear Tag Location CM_Brand CM_Brand Location CM_Tattoo  \
# 0                  NaN    C0271                RH      8075
#
#   CM_Tattoo Location  CM_Other ID  CM_Other ID Location  \
# 0                 LE          NaN                   NaN
#
#                        CM_Name                     CM_Breeder  \
# 0  ARTESIAN CATTLE C0271188075  ARTESIAN CATTLE & FARMING LLC
#
#    CM_Breeder Member Number                       CM_Owner  \
# 0                     291.0  ARTESIAN CATTLE & FARMING LLC
#
#    CM_Owner Member Number CM_Date of Birth CM_Birth Method  CM_Sire  CM_Dam  \
# 0                   291.0       2018-03-05              NS  AF31519  X93873
#
#   CM_Status CM_Type or Sex  CM_Percent Purebred  CM_Breed CM_Breed 1  \
# 0    Active              C                  NaN       NaN         AA
#
#   CM_Breed 2 CM_Breed 3  CM_Breed Comp 1  CM_Breed Comp 2  CM_Breed Comp 3  \
# 0         AN         XX             50.0             25.0             25.0
#
#   CM_Horns  CM_Color Markings CM_EPDType  CM_EPD Reporting Period  \
# 0        P                NaN          P               20240808.0
#
#    CM_Calving Ease Direct EPD  CM_Calving Ease Direct Acc  \
# 0                        -0.5                         0.1
#
#    CM_Birth Weight EPD  CM_Birth Weight Acc  CM_Weaning Weight EPD  \
# 0                  0.4                 0.08                   47.0
#
#    CM_Weaning Weight Acc  CM_Yearling Weight EPD  CM_Yearling Weight Acc  \
# 0                   0.06                    83.0                    0.01
#
#    CM_Milk EPD  CM_Milk Acc  CM_Total Maternal EPD  \
# 0         24.0         0.04                 46.999
#
#    CM_Calving Ease Maternal EPD  CM_Calving Ease Maternal Acc  \
# 0                           NaN                           NaN
#
#    CM_Scrotal Circumference EPD  CM_Scrotal Circumference Acc  \
# 0                           NaN                           NaN
#
#    CM_Ribeye Area EPD  CM_Ribeye Area Acc  CM_Marbling EPD  CM_Marbling Acc  \
# 0                 NaN                 NaN              NaN              NaN
#
#    CM_Fat Thickness EPD  CM_Fat Thickness Acc  CM_Carcass Weight EPD  \
# 0                   NaN                   NaN                    NaN
#
#    CM_Carcass Weight  Acc  CM_Percent Retail Cuts EPD  \
# 0                     NaN                         NaN
#
#    CM_Percent Retail Cuts Acc  CM_Intramuscular Fat EPD  \
# 0                         NaN                       NaN
#
#    CM_Intramuscular Fat Acc  CM_Birth Weight  CM_Adjusted Birth Weight  \
# 0                       NaN              0.0                       NaN
#
#   CM_Birth Contemp Group  CM_Birth contemporaries  CM_Birth Weight Ratio  \
# 0              6144-6271                     40.0                    NaN
#
#    CM_Birth Height  CM_Calving Ease  CM_Birth Code  CM_Nurse Code  \
# 0              NaN              1.0            NaN            NaN
#
#    CM_Twin code  CM_Dam Teat Score  CM_Dam Udder Score  \
# 0           1.0                NaN                 NaN
#
#    CM_Dam Gestation Length CM_Weaning Date CM_Weaning Weight Date  \
# 0                      NaN             NaN                    NaN
#
#    CM_Weaning Weight  CM_Adjusted Weaning Weight CM_Weaning Contemp Group  \
# 0                NaN                         NaN                      NaN
#
#    CM_Weaning Contemporaries  CM_Weaning Weight Ratio  CM_Weaning WDA  \
# 0                        NaN                      NaN             NaN
#
#    CM_Weaning Height  CM_Weaning Frame Score  CM_Weaning Mgmt Code  \
# 0                NaN                     NaN                   NaN
#
#   CM_Weaning Pasture Code  CM_Weaning Sheath/Namvel CM_Yearling Date  \
# 0                     NaN                       NaN              NaN
#
#   CM_Yearling Weight Date  CM_Yearling Weight  CM_Adjusted Yearling Weight  \
# 0                     NaN                 NaN                          NaN
#
#   CM_Yearling Contemp Group  CM_Yearling Contemporaries  \
# 0                       NaN                         NaN
#
#    CM_Yearling Weight Ratio  CM_Yearling WDA  CM_Yearling ADG  \
# 0                       NaN              NaN              NaN
#
#    CM_Yearling ADG Ratio  CM_Yearling Height  CM_Yearling Frame Score  \
# 0                    NaN                 NaN                      NaN
#
#    CM_Yearling Mgmt Code CM_Yearling Pasture Code  CM_Yearling Sheath/Navel
# 0                    NaN                      NaN                       NaN

# %%
df.dropna(axis=1, how='all', inplace=True)

# %%
with open('datafiles/activeDamsPercentileRankDf.pkl', 'rb') as f:
    df = pickle.load(f)

df.head()
# Out:
# 0   Categories   CED    BW    WW    YW    MK    TM  Growth
# 0  Num Animals  8845  8845  8845  8845  8845  8845    8845
# 1         High    15   9.3    75   122    35    72  131.80
# 2      Average    -1   1.7    43    79    26    47   79.50
# 3          Low   -14  -5.9    18    45    12    25   34.03
# 4           1%     9  -1.6    56    96    31    57  106.44
